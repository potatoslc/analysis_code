# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
d1 = '/home/u0890475/Downloads/amr2_p38p1_all.csv'
df = pd.read_csv(d1)
df
# Out:
#          time         x         y         z   plt_name Unnamed: 5    time.1
# 0    0.000000  0.070034  0.004409  0.000034   plt00000        p40  0.000000
# 1    0.001939  0.069761  0.000034  0.000034   plt00500        NaN  0.001939
# 2    0.003939  0.069692  0.000034  0.000103   plt01000        NaN  0.003939
# 3    0.005939  0.069692  0.000034  0.000034   plt01500        NaN  0.005939
# 4    0.007939  0.069624  0.003315  0.000103   plt02000        NaN  0.007939
# ..        ...       ...       ...       ...        ...        ...       ...
# 272  0.136544  0.019312  0.008032  0.000239  plt139000        NaN  0.376544
# 273  0.137544  0.017808  0.007827  0.000171  plt139500        NaN  0.377544
# 274  0.138544  0.015825  0.008101  0.000239  plt140000        NaN  0.378544
# 275  0.139544  0.013843  0.008784  0.000171  plt140500        NaN  0.379544
# 276  0.140544  0.013091  0.008784  0.000171  plt141000        NaN  0.380544
#
# [277 rows x 7 columns]

# %%
plt.scatter(df['time.1'], df['x'],s=2)
plt.xlabel('Time (sec)')
plt.ylabel('Flametip Location (m)')
#plt.axvline(x=0.043939,color='red',linestyle='--', linewidth=1.5, label='phi=0.42')
plt.axvline(x=0.150439,color='red',linestyle='--', linewidth=1.5)
plt.axvline(x=0.241103,color='red',linestyle='--', linewidth=1.5)
plt.axvline(x=0.007939,color='red',linestyle='--', linewidth=1.5)
#plt.legend()
plt.xlim(0,0.39)
plt.text(0.018,0.02,'phi=0.42')
plt.text(0.16044,0.02,'phi=0.44')
plt.text(0.25110,0.02,'phi=0.46')
plt.savefig('')
# Out:
# Text(0.2511, 0.02, 'phi=0.46')
