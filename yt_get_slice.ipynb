# %%
import yt
import pandas as pd
import numpy as np
import os
from glob import glob

# --- USER SETTINGS ---
data_dir = "/media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45"   # ← change this to your directory
out_dir = '/home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice'
header= 'p2p45'
x_min, x_max = 0.05, 0.08        # x window (after ×100 scaling)
fields = ["density", "temp", "x_velocity", "y_velocity", "z_velocity"]

# --- LOOP OVER ALL plt* DIRECTORIES ---
for plt_path in sorted(glob(os.path.join(data_dir, "plt*"))):
    if not os.path.isdir(plt_path):
        continue

    print(f"\n📂 Processing {plt_path} ...")
    ds = yt.load(plt_path)
    ad = ds.all_data()
    curr_plt = plt_path.split('/')[-1]

    # --- get raw coordinates ---
    x_raw = ad["x"].to("m").ndarray_view()
    y_raw = ad["y"].to("m").ndarray_view()
    z_raw = ad["z"].to("m").ndarray_view()
    time_val = float(ds.current_time.to_value())        
    # --- scale all coords by 100 ---
    x = x_raw * 100.0
    y = y_raw * 100.0
    z = z_raw * 100.0

    # --- select the lowest z-plane (exact match) ---
    z_lowest = np.min(z_raw)
    sel = (z_raw == z_lowest) & (x >= x_min) & (x <= x_max)

    # --- collect data ---
    data = {
        "time_s": np.full(np.count_nonzero(sel), time_val),
        "x_m": x[sel],
        "y_m": y[sel],
        "z_m": z[sel],
    }
    
    for f in fields:
        key = ("boxlib", f)
        if key in ds.field_list:
            data[f] = ad[key].ndarray_view()[sel]
        else:
            print(f"  ⚠️ Field '{f}' not found in {plt_path}")

    # --- export ---
    df = pd.DataFrame(data)
    out_csv = out_dir + '/'+header +'_'+curr_plt+'.csv'
    #print(out_csv)
    #break
    #out_csv = os.path.join(data_dir, os.path.basename(plt_path) + ".csv")
    df.to_csv(out_csv, index=False)

    print(f"✅ Saved {len(df)} lowest-z cells → {out_csv}")

print("\n🎉 Done! All lowest-z slices exported.")
# Out:
# yt : [INFO     ] 2025-11-08 19:19:55,541 Parameters: current_time              = 0.004807859478581569
# yt : [INFO     ] 2025-11-08 19:19:55,541 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:55,541 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:55,541 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt01000 ...
# yt : [INFO     ] 2025-11-08 19:19:56,381 Parameters: current_time              = 0.009807859478581366
# yt : [INFO     ] 2025-11-08 19:19:56,381 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:56,381 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:56,381 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt01000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt02000 ...
# yt : [INFO     ] 2025-11-08 19:19:57,032 Parameters: current_time              = 0.014807859478581162
# yt : [INFO     ] 2025-11-08 19:19:57,032 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:57,032 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:57,033 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt02000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt03000 ...
# yt : [INFO     ] 2025-11-08 19:19:57,640 Parameters: current_time              = 0.01980785947858241
# yt : [INFO     ] 2025-11-08 19:19:57,640 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:57,640 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:57,640 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt03000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt04000 ...
# yt : [INFO     ] 2025-11-08 19:19:58,295 Parameters: current_time              = 0.02230785947858144
# yt : [INFO     ] 2025-11-08 19:19:58,295 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:58,296 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:58,296 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt04000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt05000 ...
# yt : [INFO     ] 2025-11-08 19:19:58,941 Parameters: current_time              = 0.024807859478580472
# yt : [INFO     ] 2025-11-08 19:19:58,941 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:58,942 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:58,942 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt05000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt06000 ...
# yt : [INFO     ] 2025-11-08 19:19:59,784 Parameters: current_time              = 0.027307859478579503
# yt : [INFO     ] 2025-11-08 19:19:59,785 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:19:59,785 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:19:59,785 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt06000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt07000 ...
# yt : [INFO     ] 2025-11-08 19:20:00,475 Parameters: current_time              = 0.029807859478578533
# yt : [INFO     ] 2025-11-08 19:20:00,475 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:20:00,475 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:20:00,475 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt07000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt08000 ...
# yt : [INFO     ] 2025-11-08 19:20:01,138 Parameters: current_time              = 0.03230785947857903
# yt : [INFO     ] 2025-11-08 19:20:01,138 Parameters: domain_dimensions         = [384  64  64]
# yt : [INFO     ] 2025-11-08 19:20:01,139 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-11-08 19:20:01,139 Parameters: domain_right_edge         = [0.105  0.0175 0.0175]
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt08000.csv
#
# 📂 Processing /media/u0890475/6f7f5b18-6951-4d23-9e1b-146d3d4c2671/SW_cache/nrel_result/amr0_p45/plt09000 ...
# ✅ Saved 28032 lowest-z cells → /home/u0890475/Documents/SW_analysis/20251108_amr0_p40p45_fb_slice/p2p45_plt09000.csv
#
# 🎉 Done! All lowest-z slices exported.

# %%
len(y[sel])
# Out:
# 28032
